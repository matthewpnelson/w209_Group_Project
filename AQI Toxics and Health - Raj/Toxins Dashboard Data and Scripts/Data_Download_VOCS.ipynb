# %%
import wget
import numpy as np
import zipfile
import os

A = np.arange(1980, 2018, 1)

for i in A:
    url = "https://aqs.epa.gov/aqsweb/airdata/daily_VOCS_" + str(i) +".zip"
    zipn = "/Users/srinivvx/Desktop/w209 Dashboard/w209_Group_Project-master/Data/Toxics-VOCS-Daily/daily_VOCS_" + str(i) +".zip"
    wget.download(url)
    zp = zipfile.ZipFile(zipn) 
    zp.extractall('/Users/srinivvx/Desktop/w209 Dashboard/w209_Group_Project-master/Data/Toxics-VOCS-Daily/')
    os.remove(zipn)

# %%
import csv
import os
# import subprocess

# Grab file names from the folder (specify the folder)
def get_file_names():
    file_list = []
    for filename in os.listdir("/Users/srinivvx/Desktop/w209 Dashboard/w209_Group_Project-master/Data/Toxics-VOCS-Daily"):
        file_list.append("/Users/srinivvx/Desktop/w209 Dashboard/w209_Group_Project-master/Data/Toxics-VOCS-Daily/"+str(filename))
    return file_list

# Delete and Create the Output File

# try:
#     os.remove("C:/Users/User/Documents/Berkeley/data_visualizations/Final Project/Data/EPA AQI - Daily - County/county_AQI.csv")
# except:
#     pass

# # Make sub directories (if not already created)
# bash_call = "mkdir "+str(uncompressed_folder)+"success"
# subprocess.call(bash_call, shell=True)


# Get file names in current folder
file_names = get_file_names()

def mygen(row, year):
    # for row in reader:
        # print(year + "," + row)
        yield year + "," + row

with open("/Users/srinivvx/Desktop/w209 Dashboard/w209_Group_Project-master/Data/Toxics-VOCS-Daily/Toxics_VOCS_Consolidated.csv", 'wt+') as fout:
    linewriter = csv.writer(fout, delimiter=',',# newline=''
                            quoting=csv.QUOTE_MINIMAL, lineterminator='\r')
    total_rows_imported = 0
    for each in file_names:
        year = str(each[-8:-4])
        file_rows_imported = 0
        try:
            if (int(year) > 1979) and (int(year) < 2018):
                print(year)
                # print(each)
                with open(each, 'rt') as fin:
                    linereader = csv.reader(fin, delimiter=',')

                    # Add header if no rows imported yet
                    if total_rows_imported == 0:
                        for row in linereader:
                            linewriter.writerow(row)
                            total_rows_imported += 1
                            break
                    for row in linereader:
                        # Skip Header Row
                        if file_rows_imported == 0:
                            file_rows_imported += 1
                            total_rows_imported += 1
                            continue
                        # Add all Rows
                        else:
                            linewriter.writerow(row)
                            file_rows_imported += 1
                            total_rows_imported += 1
                        # linewriter.writerow(mygen(row, year))

            else:
                continue
        except:
            continue
        print("Rows Imported %i" %file_rows_imported)
        print("Total Rows Imported %i" %total_rows_imported)
# Out:
# 1980
# Rows Imported 14807
# Total Rows Imported 14808
# 1981
# Rows Imported 13401
# Total Rows Imported 28209
# 1982
# Rows Imported 7781
# Total Rows Imported 35990
# 1983
# Rows Imported 4946
# Total Rows Imported 40936
# 1984
# Rows Imported 4343
# Total Rows Imported 45279
# 1985
# Rows Imported 17208
# Total Rows Imported 62487
# 1986
# Rows Imported 12926
# Total Rows Imported 75413
# 1987
# Rows Imported 17579
# Total Rows Imported 92992
# 1988
# Rows Imported 28124
# Total Rows Imported 121116
# 1989
# Rows Imported 36152
# Total Rows Imported 157268
# 1990
# Rows Imported 33672
# Total Rows Imported 190940
# 1991
# Rows Imported 54674
# Total Rows Imported 245614
# 1992
# Rows Imported 70702
# Total Rows Imported 316316
# 1993
# Rows Imported 158561
# Total Rows Imported 474877
# 1994
# Rows Imported 266320
# Total Rows Imported 741197
# 1995
# Rows Imported 451405
# Total Rows Imported 1192602
# 1996
# Rows Imported 602512
# Total Rows Imported 1795114
# 1997
# Rows Imported 693550
# Total Rows Imported 2488664
# 1998
# Rows Imported 787135
# Total Rows Imported 3275799
# 1999
# Rows Imported 856719
# Total Rows Imported 4132518
# 2000
# Rows Imported 905638
# Total Rows Imported 5038156
# 2001
# Rows Imported 1076005
# Total Rows Imported 6114161
# 2002
# Rows Imported 1101838
# Total Rows Imported 7215999
# 2003
# Rows Imported 1115998
# Total Rows Imported 8331997
# 2004
# Rows Imported 1165861
# Total Rows Imported 9497858
# 2005
# Rows Imported 1279459
# Total Rows Imported 10777317
# 2006
# Rows Imported 1332445
# Total Rows Imported 12109762
# 2007
# Rows Imported 1366553
# Total Rows Imported 13476315
# 2008
# Rows Imported 1256955
# Total Rows Imported 14733270
# 2009
# Rows Imported 1262372
# Total Rows Imported 15995642
# 2010
# Rows Imported 1288897
# Total Rows Imported 17284539
# 2011
# Rows Imported 1288121
# Total Rows Imported 18572660
# 2012
# Rows Imported 1280899
# Total Rows Imported 19853559
# 2013
# Rows Imported 1242268
# Total Rows Imported 21095827
# 2014
# Rows Imported 1161585
# Total Rows Imported 22257412
# 2015
# Rows Imported 896499
# Total Rows Imported 23153911
# 2016
# Rows Imported 771090
# Total Rows Imported 23925001
# 2017
# Rows Imported 30269
# Total Rows Imported 23955270
