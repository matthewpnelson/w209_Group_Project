# %%
import wget
import numpy as np
import zipfile
import os

A = np.arange(1980, 2018, 1)

for i in A:
    url = "https://aqs.epa.gov/aqsweb/airdata/daily_HAPS_" + str(i) +".zip"
    zipn = "/Users/srinivvx/Desktop/w209 Dashboard/w209_Group_Project-master/Data/Toxics-HAPS-Daily/daily_HAPS_" + str(i) +".zip"
    wget.download(url)
    zp = zipfile.ZipFile(zipn) 
    zp.extractall('/Users/srinivvx/Desktop/w209 Dashboard/w209_Group_Project-master/Data/Toxics-HAPS-Daily/')
    os.remove(zipn)

# %%
import csv
import os
# import subprocess

# Grab file names from the folder (specify the folder)
def get_file_names():
    file_list = []
    for filename in os.listdir("/Users/srinivvx/Desktop/w209 Dashboard/w209_Group_Project-master/Data/Toxics-HAPS-Daily"):
        file_list.append("/Users/srinivvx/Desktop/w209 Dashboard/w209_Group_Project-master/Data/Toxics-HAPS-Daily/"+str(filename))
    return file_list

# Delete and Create the Output File

# try:
#     os.remove("C:/Users/User/Documents/Berkeley/data_visualizations/Final Project/Data/EPA AQI - Daily - County/county_AQI.csv")
# except:
#     pass

# # Make sub directories (if not already created)
# bash_call = "mkdir "+str(uncompressed_folder)+"success"
# subprocess.call(bash_call, shell=True)


# Get file names in current folder
file_names = get_file_names()

def mygen(row, year):
    # for row in reader:
        # print(year + "," + row)
        yield year + "," + row

with open("/Users/srinivvx/Desktop/w209 Dashboard/w209_Group_Project-master/Data/Toxics-HAPS-Daily/Toxics_HAPS_Consolidated.csv", 'wt+') as fout:
    linewriter = csv.writer(fout, delimiter=',',# newline=''
                            quoting=csv.QUOTE_MINIMAL, lineterminator='\r')
    total_rows_imported = 0
    for each in file_names:
        year = str(each[-8:-4])
        file_rows_imported = 0
        try:
            if (int(year) > 1979) and (int(year) < 2018):
                print(year)
                # print(each)
                with open(each, 'rt') as fin:
                    linereader = csv.reader(fin, delimiter=',')

                    # Add header if no rows imported yet
                    if total_rows_imported == 0:
                        for row in linereader:
                            linewriter.writerow(row)
                            total_rows_imported += 1
                            break
                    for row in linereader:
                        # Skip Header Row
                        if file_rows_imported == 0:
                            file_rows_imported += 1
                            total_rows_imported += 1
                            continue
                        # Add all Rows
                        else:
                            linewriter.writerow(row)
                            file_rows_imported += 1
                            total_rows_imported += 1
                        # linewriter.writerow(mygen(row, year))

            else:
                continue
        except:
            continue
        print("Rows Imported %i" %file_rows_imported)
        print("Total Rows Imported %i" %total_rows_imported)
# Out:
# 1980
# Rows Imported 46524
# Total Rows Imported 46525
# 1981
# Rows Imported 50669
# Total Rows Imported 97194
# 1982
# Rows Imported 35289
# Total Rows Imported 132483
# 1983
# Rows Imported 37728
# Total Rows Imported 170211
# 1984
# Rows Imported 40788
# Total Rows Imported 210999
# 1985
# Rows Imported 64299
# Total Rows Imported 275298
# 1986
# Rows Imported 64506
# Total Rows Imported 339804
# 1987
# Rows Imported 66894
# Total Rows Imported 406698
# 1988
# Rows Imported 67876
# Total Rows Imported 474574
# 1989
# Rows Imported 67180
# Total Rows Imported 541754
# 1990
# Rows Imported 73080
# Total Rows Imported 614834
# 1991
# Rows Imported 83635
# Total Rows Imported 698469
# 1992
# Rows Imported 91185
# Total Rows Imported 789654
# 1993
# Rows Imported 98877
# Total Rows Imported 888531
# 1994
# Rows Imported 122421
# Total Rows Imported 1010952
# 1995
# Rows Imported 139262
# Total Rows Imported 1150214
# 1996
# Rows Imported 156916
# Total Rows Imported 1307130
# 1997
# Rows Imported 165283
# Total Rows Imported 1472413
# 1998
# Rows Imported 158865
# Total Rows Imported 1631278
# 1999
# Rows Imported 163612
# Total Rows Imported 1794890
# 2000
# Rows Imported 210510
# Total Rows Imported 2005400
# 2001
# Rows Imported 307268
# Total Rows Imported 2312668
# 2002
# Rows Imported 390276
# Total Rows Imported 2702944
# 2003
# Rows Imported 418567
# Total Rows Imported 3121511
# 2004
# Rows Imported 443804
# Total Rows Imported 3565315
# 2005
# Rows Imported 487527
# Total Rows Imported 4052842
# 2006
# Rows Imported 468843
# Total Rows Imported 4521685
# 2007
# Rows Imported 467361
# Total Rows Imported 4989046
# 2008
# Rows Imported 452399
# Total Rows Imported 5441445
# 2009
# Rows Imported 455686
# Total Rows Imported 5897131
# 2010
# Rows Imported 443644
# Total Rows Imported 6340775
# 2011
# Rows Imported 431112
# Total Rows Imported 6771887
# 2012
# Rows Imported 434275
# Total Rows Imported 7206162
# 2013
# Rows Imported 420394
# Total Rows Imported 7626556
# 2014
# Rows Imported 402608
# Total Rows Imported 8029164
# 2015
# Rows Imported 357307
# Total Rows Imported 8386471
# 2016
# Rows Imported 243797
# Total Rows Imported 8630268
# 2017
# Rows Imported 8583
# Total Rows Imported 8638851

# %%
import pandas as pd
df1 = pd.read_csv("/Users/srinivvx/Desktop/w209 Dashboard/w209_Group_Project-master/Data/Toxics-HAPS-Daily/Toxics_HAPS_Consolidated.csv")
df2 = pd.read_csv("cbsas.csv")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-e6b61bcccc77> in <module>()
#       1 import pandas as pd
# ----> 2 df1 = pd.read_csv("/Users/srinivvx/Desktop/w209 Dashboard/w209_Group_Project-master/Data/Toxics-HAPS-Daily/Toxics_HAPS_Consolidated.csv")
#       3 df2 = pd.read_csv("cbsas.csv")
#
# /anaconda/lib/python2.7/site-packages/pandas/io/parsers.pyc in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, skip_footer, doublequote, delim_whitespace, as_recarray, compact_ints, use_unsigned, low_memory, buffer_lines, memory_map, float_precision)
#     653                     skip_blank_lines=skip_blank_lines)
#     654
# --> 655         return _read(filepath_or_buffer, kwds)
#     656
#     657     parser_f.__name__ = name
#
# /anaconda/lib/python2.7/site-packages/pandas/io/parsers.pyc in _read(filepath_or_buffer, kwds)
#     409
#     410     try:
# --> 411         data = parser.read(nrows)
#     412     finally:
#     413         parser.close()
#
# /anaconda/lib/python2.7/site-packages/pandas/io/parsers.pyc in read(self, nrows)
#     980                 raise ValueError('skipfooter not supported for iteration')
#     981
# --> 982         ret = self._engine.read(nrows)
#     983
#     984         if self.options.get('as_recarray'):
#
# /anaconda/lib/python2.7/site-packages/pandas/io/parsers.pyc in read(self, nrows)
#    1717     def read(self, nrows=None):
#    1718         try:
# -> 1719             data = self._reader.read(nrows)
#    1720         except StopIteration:
#    1721             if self._first_chunk:
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.read (pandas/_libs/parsers.c:10862)()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_low_memory (pandas/_libs/parsers.c:11138)()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_rows (pandas/_libs/parsers.c:12175)()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_column_data (pandas/_libs/parsers.c:14136)()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_tokens (pandas/_libs/parsers.c:14858)()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_with_dtype (pandas/_libs/parsers.c:15629)()
#
# /anaconda/lib/python2.7/site-packages/pandas/core/dtypes/common.pyc in is_integer_dtype(arr_or_dtype)
#     735
#     736
# --> 737 def is_integer_dtype(arr_or_dtype):
#     738     """
#     739     Check whether the provided array or dtype is of an integer dtype.
#
# KeyboardInterrupt:

# %%
result = pd.merge(df1, df2, how='left', on=['CBSA Name'])

# %%
result.to_csv(path_or_buf="/Users/srinivvx/Desktop/w209 Dashboard/w209_Group_Project-master/Data/Toxics-HAPS-Daily/Toxics_HAPS_Consolidated.csv", header=True, index=True, index_label="row_num")

# %%
result
