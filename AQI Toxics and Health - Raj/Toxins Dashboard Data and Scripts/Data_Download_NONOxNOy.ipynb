# %%
import wget
import numpy as np
import zipfile
import os

A = np.arange(1980, 2018, 1)

for i in A:
    url = "https://aqs.epa.gov/aqsweb/airdata/daily_NONOxNOy_" + str(i) +".zip"
    zipn = "/Users/srinivvx/Desktop/w209 Dashboard/w209_Group_Project-master/Data/Toxics-NONOxNOy-Daily/daily_NONOxNOy_" + str(i) +".zip"
    wget.download(url)
    zp = zipfile.ZipFile(zipn) 
    zp.extractall('/Users/srinivvx/Desktop/w209 Dashboard/w209_Group_Project-master/Data/Toxics-NONOxNOy-Daily/')
    os.remove(zipn)

# %%
import csv
import os
# import subprocess

# Grab file names from the folder (specify the folder)
def get_file_names():
    file_list = []
    for filename in os.listdir("/Users/srinivvx/Desktop/w209 Dashboard/w209_Group_Project-master/Data/Toxics-NONOxNOy-Daily"):
        file_list.append("/Users/srinivvx/Desktop/w209 Dashboard/w209_Group_Project-master/Data/Toxics-NONOxNOy-Daily/"+str(filename))
    return file_list

# Delete and Create the Output File

# try:
#     os.remove("C:/Users/User/Documents/Berkeley/data_visualizations/Final Project/Data/EPA AQI - Daily - County/county_AQI.csv")
# except:
#     pass

# # Make sub directories (if not already created)
# bash_call = "mkdir "+str(uncompressed_folder)+"success"
# subprocess.call(bash_call, shell=True)


# Get file names in current folder
file_names = get_file_names()

def mygen(row, year):
    # for row in reader:
        # print(year + "," + row)
        yield year + "," + row

with open("/Users/srinivvx/Desktop/w209 Dashboard/w209_Group_Project-master/Data/Toxics-NONOxNOy-Daily/Toxics_NONOxNOy_Consolidated.csv", 'wt+') as fout:
    linewriter = csv.writer(fout, delimiter=',',# newline=''
                            quoting=csv.QUOTE_MINIMAL, lineterminator='\r')
    total_rows_imported = 0
    for each in file_names:
        year = str(each[-8:-4])
        file_rows_imported = 0
        try:
            if (int(year) > 1979) and (int(year) < 2018):
                print(year)
                # print(each)
                with open(each, 'rt') as fin:
                    linereader = csv.reader(fin, delimiter=',')

                    # Add header if no rows imported yet
                    if total_rows_imported == 0:
                        for row in linereader:
                            linewriter.writerow(row)
                            total_rows_imported += 1
                            break
                    for row in linereader:
                        # Skip Header Row
                        if file_rows_imported == 0:
                            file_rows_imported += 1
                            total_rows_imported += 1
                            continue
                        # Add all Rows
                        else:
                            linewriter.writerow(row)
                            file_rows_imported += 1
                            total_rows_imported += 1
                        # linewriter.writerow(mygen(row, year))

            else:
                continue
        except:
            continue
        print("Rows Imported %i" %file_rows_imported)
        print("Total Rows Imported %i" %total_rows_imported)
# Out:
# 1980
# Rows Imported 86830
# Total Rows Imported 86831
# 1981
# Rows Imported 92552
# Total Rows Imported 179383
# 1982
# Rows Imported 89992
# Total Rows Imported 269375
# 1983
# Rows Imported 88460
# Total Rows Imported 357835
# 1984
# Rows Imported 99816
# Total Rows Imported 457651
# 1985
# Rows Imported 93674
# Total Rows Imported 551325
# 1986
# Rows Imported 90122
# Total Rows Imported 641447
# 1987
# Rows Imported 106129
# Total Rows Imported 747576
# 1988
# Rows Imported 76668
# Total Rows Imported 824244
# 1989
# Rows Imported 83047
# Total Rows Imported 907291
# 1990
# Rows Imported 86556
# Total Rows Imported 993847
# 1991
# Rows Imported 106911
# Total Rows Imported 1100758
# 1992
# Rows Imported 112965
# Total Rows Imported 1213723
# 1993
# Rows Imported 125090
# Total Rows Imported 1338813
# 1994
# Rows Imported 175903
# Total Rows Imported 1514716
# 1995
# Rows Imported 192504
# Total Rows Imported 1707220
# 1996
# Rows Imported 194411
# Total Rows Imported 1901631
# 1997
# Rows Imported 196077
# Total Rows Imported 2097708
# 1998
# Rows Imported 201972
# Total Rows Imported 2299680
# 1999
# Rows Imported 210940
# Total Rows Imported 2510620
# 2000
# Rows Imported 213822
# Total Rows Imported 2724442
# 2001
# Rows Imported 219222
# Total Rows Imported 2943664
# 2002
# Rows Imported 224028
# Total Rows Imported 3167692
# 2003
# Rows Imported 225312
# Total Rows Imported 3393004
# 2004
# Rows Imported 229022
# Total Rows Imported 3622026
# 2005
# Rows Imported 228466
# Total Rows Imported 3850492
# 2006
# Rows Imported 233625
# Total Rows Imported 4084117
# 2007
# Rows Imported 252333
# Total Rows Imported 4336450
# 2008
# Rows Imported 257446
# Total Rows Imported 4593896
# 2009
# Rows Imported 253629
# Total Rows Imported 4847525
# 2010
# Rows Imported 264683
# Total Rows Imported 5112208
# 2011
# Rows Imported 289965
# Total Rows Imported 5402173
# 2012
# Rows Imported 301294
# Total Rows Imported 5703467
# 2013
# Rows Imported 316191
# Total Rows Imported 6019658
# 2014
# Rows Imported 341009
# Total Rows Imported 6360667
# 2015
# Rows Imported 346451
# Total Rows Imported 6707118
# 2016
# Rows Imported 348819
# Total Rows Imported 7055937
# 2017
# Rows Imported 48533
# Total Rows Imported 7104470

# %%
import pandas as pd
df1 = pd.read_csv("/Users/srinivvx/Desktop/w209 Dashboard/w209_Group_Project-master/Data/Toxics-NONOxNOy-Daily/Toxics_NONOxNOy_Consolidated.csv")
df2 = pd.read_csv("cbsas.csv")

# %%
result = pd.merge(df1, df2, how='left', on=['CBSA Name'])

# %%
result.to_csv(path_or_buf="/Users/srinivvx/Desktop/w209 Dashboard/w209_Group_Project-master/Data/Toxics-NONOxNOy-Daily/Toxics_NONOxNOy_Consolidated.csv", header=True, index=True, index_label="row_num")
