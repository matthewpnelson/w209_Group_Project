# %%
import pandas as pd
df1=pd.read_csv("Toxics_HAPS_Consolidated.csv")
df1['TOXIC_CAT'] = "HAPS"

# %%
df1
# Out:
#          row_num  State Code  County Code  Site Num  Parameter Code  POC  \
# 0              0           1           89         3           12103    1
# 1              1           1           89         3           12103    1
# 2              2           1           89         3           12103    1
# 3              3           1           89         3           12103    1
# 4              4           1           89         3           12103    1
# 5              5           1           89         3           12103    1
# 6              6           1           89         3           12103    1
# 7              7           1           89         3           12103    1
# 8              8           1           89         3           12103    1
# 9              9           1           89         3           12103    1
# 10            10           1           89         3           12103    1
# 11            11           1           89         3           12103    1
# ...

# %%
df2=pd.read_csv("Toxics_Lead_Consolidated.csv")
df2['TOXIC_CAT'] = "Lead"

# %%
df3=pd.read_csv("Toxics_NONOxNOy_Consolidated.csv")
df3['TOXIC_CAT'] = "NONOxNOy"

# %%
df4=pd.read_csv("Toxics_VOCS_Consolidated.csv")
df4['TOXIC_CAT'] = "VOCS"

# %%
df5=pd.concat([df1, df2,df3,df4])

# %%
df5.head()
# Out:
#    1st Max Hour  1st Max Value  AQI         Address  Arithmetic Mean  \
# 0             0            0.0  NaN  MADISON STREET              0.0
# 1             0            0.0  NaN  MADISON STREET              0.0
# 2             0            0.0  NaN  MADISON STREET              0.0
# 3             0            0.0  NaN  MADISON STREET              0.0
# 4             0            0.0  NaN  MADISON STREET              0.0
#
#    CBSA Code       CBSA Name     CBSA Type   City Name  County Code   ...    \
# 0    26620.0  Huntsville, AL  Metropolitan  Huntsville           89   ...
# 1    26620.0  Huntsville, AL  Metropolitan  Huntsville           89   ...
# 2    26620.0  Huntsville, AL  Metropolitan  Huntsville           89   ...
# 3    26620.0  Huntsville, AL  Metropolitan  Huntsville           89   ...
# 4    26620.0  Huntsville, AL  Metropolitan  Huntsville           89   ...
#
#   Parameter Code     Parameter Name Pollutant Standard Sample Duration  \
# ...

# %%
df5.to_csv("Toxics_All_Consolidated.csv")

# %%
df3['Units of Measure'].head()
# Out:
# 0    Parts per billion
# 1    Parts per billion
# 2    Parts per billion
# 3    Parts per billion
# 4    Parts per billion
# Name: Units of Measure, dtype: object

# %%
df5=pd.read_csv("Toxics_All_Consolidated.csv")
# Out:
# /anaconda/lib/python2.7/site-packages/IPython/core/interactiveshell.py:2717: DtypeWarning: Columns (8,26) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df5.head()
# Out:
#    Unnamed: 0  1st Max Hour  1st Max Value  AQI         Address  \
# 0           0             0            0.0  NaN  MADISON STREET
# 1           1             0            0.0  NaN  MADISON STREET
# 2           2             0            0.0  NaN  MADISON STREET
# 3           3             0            0.0  NaN  MADISON STREET
# 4           4             0            0.0  NaN  MADISON STREET
#
#    Arithmetic Mean  CBSA Code       CBSA Name     CBSA Type   City Name  \
# 0              0.0    26620.0  Huntsville, AL  Metropolitan  Huntsville
# 1              0.0    26620.0  Huntsville, AL  Metropolitan  Huntsville
# 2              0.0    26620.0  Huntsville, AL  Metropolitan  Huntsville
# 3              0.0    26620.0  Huntsville, AL  Metropolitan  Huntsville
# 4              0.0    26620.0  Huntsville, AL  Metropolitan  Huntsville
#
#     ...     Parameter Code     Parameter Name Pollutant Standard  \
# 0   ...              12103  Arsenic (TSP) STP                NaN
# ...

# %%
df5['Year'] =pd.DatetimeIndex(df5['Date Local']).year

# %%
df5.head()
# Out:
#    Unnamed: 0  1st Max Hour  1st Max Value  AQI         Address  \
# 0           0             0            0.0  NaN  MADISON STREET
# 1           1             0            0.0  NaN  MADISON STREET
# 2           2             0            0.0  NaN  MADISON STREET
# 3           3             0            0.0  NaN  MADISON STREET
# 4           4             0            0.0  NaN  MADISON STREET
#
#    Arithmetic Mean  CBSA Code       CBSA Name     CBSA Type   City Name  ...   \
# 0              0.0    26620.0  Huntsville, AL  Metropolitan  Huntsville  ...
# 1              0.0    26620.0  Huntsville, AL  Metropolitan  Huntsville  ...
# 2              0.0    26620.0  Huntsville, AL  Metropolitan  Huntsville  ...
# 3              0.0    26620.0  Huntsville, AL  Metropolitan  Huntsville  ...
# 4              0.0    26620.0  Huntsville, AL  Metropolitan  Huntsville  ...
#
#       Parameter Name Pollutant Standard Sample Duration Site Num State Code  \
# ...

# %%
report = df5.groupby(['State Name', 'TOXIC_CAT', 'Year' ]).mean()
report2 = report.add_suffix('_Avg').reset_index()

# %%
report2.head()
# Out:
#   State Name TOXIC_CAT  Year  Unnamed: 0_Avg  1st Max Hour_Avg  \
# 0    Alabama      HAPS  1980           104.0               0.0
# 1    Alabama      HAPS  1981         46926.5               0.0
# 2    Alabama      HAPS  1982         97625.5               0.0
# 3    Alabama      HAPS  1983        132865.5               0.0
# 4    Alabama      HAPS  1984        170634.5               0.0
#
#    1st Max Value_Avg  AQI_Avg  Arithmetic Mean_Avg  CBSA Code_Avg  \
# 0           0.006253      NaN             0.006253   26620.000000
# 1           0.031390      NaN             0.031390   22899.603960
# 2           0.028738      NaN             0.028738   22245.379310
# 3           0.027647      NaN             0.027647   21056.589147
# 4           0.011819      NaN             0.011819   21238.601399
#
#    County Code_Avg  Latitude_Avg  Longitude_Avg  Method Code_Avg  \
# 0        89.000000     34.728831     -86.585003        92.258373
# ...

# %%
report3 = report2.loc[report2['Year'].isin([1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014])]

# %%
report3.head()
# Out:
#    State Name TOXIC_CAT  Year  Unnamed: 0_Avg  1st Max Hour_Avg  \
# 18    Alabama      HAPS  1999       1631475.0          0.000000
# 19    Alabama      HAPS  2000       1795096.0          0.000000
# 20    Alabama      HAPS  2001       2006046.5          0.000000
# 21    Alabama      HAPS  2002       2315365.0          0.015438
# 22    Alabama      HAPS  2003       2706871.0          0.000000
#
#     1st Max Value_Avg  AQI_Avg  Arithmetic Mean_Avg  CBSA Code_Avg  \
# 18           0.001443      NaN             0.001443   19460.000000
# 19           0.001207      NaN             0.001207   19460.000000
# 20           0.009025      NaN             0.009025   15969.775785
# 21           0.113780      NaN             0.113780   26249.693071
# 22           0.140777      NaN             0.140777   28054.017462
#
#     County Code_Avg  Latitude_Avg  Longitude_Avg  Method Code_Avg  \
# 18        79.000000     34.342904     -87.339730       801.000000
# ...

# %%
report3.to_csv("Toxics_Avg_Annual_Conc_by State.csv")

# %%
df5.groupby(['Year']).count()
# Out:
#       Unnamed: 0  1st Max Hour  1st Max Value  AQI  Address  Arithmetic Mean  \
# Year
# 1980      175476        175476         175476    0   175476           175476
# 1981      189623        189623         189623    0   189623           189623
# 1982      161005        161005         161005    0   161005           161005
# 1983      164427        164427         164427    0   164427           164427
# 1984      178192        178192         178192    0   178192           178192
# 1985      217157        217157         217157    0   217157           217157
# 1986      207986        207986         207986    0   207986           207986
# 1987      226469        226469         226469    0   226469           226469
# 1988      201379        201379         201379    0   201379           201379
# 1989      211648        211648         211648    0   211648           211648
# 1990      220247        220247         220247    0   220247           220247
# ...

# %%
df5.columns
# Out:
# Index([u'Unnamed: 0', u'1st Max Hour', u'1st Max Value', u'AQI', u'Address',
#        u'Arithmetic Mean', u'CBSA Code', u'CBSA Name', u'CBSA Type',
#        u'City Name', u'County Code', u'County Name', u'Date Local',
#        u'Date of Last Change', u'Datum', u'Event Type', u'Latitude',
#        u'Local Site Name', u'Longitude', u'Method Code', u'Method Name',
#        u'Observation Count', u'Observation Percent', u'POC', u'Parameter Code',
#        u'Parameter Name', u'Pollutant Standard', u'Sample Duration',
#        u'Site Num', u'State Code', u'State Name', u'TOXIC_CAT',
#        u'Units of Measure', u'row_num', u'Year'],
#       dtype='object')
