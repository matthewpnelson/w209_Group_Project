# %%
import wget
import numpy as np
import zipfile
import os

A = np.arange(1980, 2018, 1)

for i in A:
    url = "https://aqs.epa.gov/aqsweb/airdata/daily_LEAD_" + str(i) +".zip"
    zipn = "/Users/srinivvx/Desktop/w209 Dashboard/w209_Group_Project-master/Data/Toxics-Lead-Daily/daily_LEAD_" + str(i) +".zip"
    wget.download(url)
    zp = zipfile.ZipFile(zipn) 
    zp.extractall('/Users/srinivvx/Desktop/w209 Dashboard/w209_Group_Project-master/Data/Toxics-Lead-Daily/')
    os.remove(zipn)

# %%
import csv
import os
# import subprocess

# Grab file names from the folder (specify the folder)
def get_file_names():
    file_list = []
    for filename in os.listdir("/Users/srinivvx/Desktop/w209 Dashboard/w209_Group_Project-master/Data/Toxics-Lead-Daily"):
        file_list.append("/Users/srinivvx/Desktop/w209 Dashboard/w209_Group_Project-master/Data/Toxics-Lead-Daily/"+str(filename))
    return file_list

# Delete and Create the Output File

# try:
#     os.remove("C:/Users/User/Documents/Berkeley/data_visualizations/Final Project/Data/EPA AQI - Daily - County/county_AQI.csv")
# except:
#     pass

# # Make sub directories (if not already created)
# bash_call = "mkdir "+str(uncompressed_folder)+"success"
# subprocess.call(bash_call, shell=True)


# Get file names in current folder
file_names = get_file_names()

def mygen(row, year):
    # for row in reader:
        # print(year + "," + row)
        yield year + "," + row

with open("/Users/srinivvx/Desktop/w209 Dashboard/w209_Group_Project-master/Data/Toxics-Lead-Daily/Toxics_Lead_Consolidated.csv", 'wt+') as fout:
    linewriter = csv.writer(fout, delimiter=',',# newline=''
                            quoting=csv.QUOTE_MINIMAL, lineterminator='\r')
    total_rows_imported = 0
    for each in file_names:
        year = str(each[-8:-4])
        file_rows_imported = 0
        try:
            if (int(year) > 1979) and (int(year) < 2018):
                print(year)
                # print(each)
                with open(each, 'rt') as fin:
                    linereader = csv.reader(fin, delimiter=',')

                    # Add header if no rows imported yet
                    if total_rows_imported == 0:
                        for row in linereader:
                            linewriter.writerow(row)
                            total_rows_imported += 1
                            break
                    for row in linereader:
                        # Skip Header Row
                        if file_rows_imported == 0:
                            file_rows_imported += 1
                            total_rows_imported += 1
                            continue
                        # Add all Rows
                        else:
                            linewriter.writerow(row)
                            file_rows_imported += 1
                            total_rows_imported += 1
                        # linewriter.writerow(mygen(row, year))

            else:
                continue
        except:
            continue
        print("Rows Imported %i" %file_rows_imported)
        print("Total Rows Imported %i" %total_rows_imported)
# Out:
# 1980
# Rows Imported 27319
# Total Rows Imported 27320
# 1981
# Rows Imported 33005
# Total Rows Imported 60325
# 1982
# Rows Imported 27947
# Total Rows Imported 88272
# 1983
# Rows Imported 33297
# Total Rows Imported 121569
# 1984
# Rows Imported 33249
# Total Rows Imported 154818
# 1985
# Rows Imported 41980
# Total Rows Imported 196798
# 1986
# Rows Imported 40436
# Total Rows Imported 237234
# 1987
# Rows Imported 35871
# Total Rows Imported 273105
# 1988
# Rows Imported 28715
# Total Rows Imported 301820
# 1989
# Rows Imported 25273
# Total Rows Imported 327093
# 1990
# Rows Imported 26943
# Total Rows Imported 354036
# 1991
# Rows Imported 26248
# Total Rows Imported 380284
# 1992
# Rows Imported 26483
# Total Rows Imported 406767
# 1993
# Rows Imported 27414
# Total Rows Imported 434181
# 1994
# Rows Imported 26417
# Total Rows Imported 460598
# 1995
# Rows Imported 24714
# Total Rows Imported 485312
# 1996
# Rows Imported 23978
# Total Rows Imported 509290
# 1997
# ...

# %%
import pandas as pd
df1 = pd.read_csv("/Users/srinivvx/Desktop/w209 Dashboard/w209_Group_Project-master/Data/Toxics-Lead-Daily/Toxics_Lead_Consolidated.csv")
df2 = pd.read_csv("cbsas.csv")

# %%
df1
# Out:
#         State Code  County Code  Site Num  Parameter Code  POC   Latitude  \
# 0                1           89         3           12128    1  34.728831
# 1                1           89         3           12128    1  34.728831
# 2                1           89         3           12128    1  34.728831
# 3                1           89         3           12128    1  34.728831
# 4                1           89         3           12128    1  34.728831
# 5                1           89         3           12128    1  34.728831
# 6                1           89         3           12128    1  34.728831
# 7                1           89         3           12128    1  34.728831
# 8                1           89         3           12128    1  34.728831
# 9                1           89         3           12128    1  34.728831
# 10               1           89         3           12128    1  34.728831
# 11               1           89         3           12128    1  34.728831
# ...

# %%
df2
# Out:
#       CBSA Code                          CBSA Name     CBSA Type
# 0         10020                      Abbeville, LA  Micropolitan
# 1         10100                       Aberdeen, SD  Micropolitan
# 2         10140                       Aberdeen, WA  Micropolitan
# 3         10180                        Abilene, TX  Metropolitan
# 4         10220                            Ada, OK  Micropolitan
# 5         10260                       Adjuntas, PR  Micropolitan
# 6         10300                         Adrian, MI  Micropolitan
# 7         10380              Aguadilla-Isabela, PR  Metropolitan
# 8         10420                          Akron, OH  Metropolitan
# 9         10460                     Alamogordo, NM  Micropolitan
# 10        10500                         Albany, GA  Metropolitan
# 11        10540                         Albany, OR  Metropolitan
# 12        10580        Albany-Schenectady-Troy, NY  Metropolitan
# ...

# %%
result = pd.merge(df1, df2, how='left', on=['CBSA Name'])
result['CBSA Code'] = result['CBSA Code'].astype(int) #.apply(pd.to_numeric)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-a30b05a0b2fe> in <module>()
#       1 result = pd.merge(df1, df2, how='left', on=['CBSA Name'])
# ----> 2 result['CBSA Code'] = result['CBSA Code'].astype(int) #.apply(pd.to_numeric)
#
# /anaconda/lib/python2.7/site-packages/pandas/util/_decorators.pyc in wrapper(*args, **kwargs)
#      89                 else:
#      90                     kwargs[new_arg_name] = new_arg_value
# ---> 91             return func(*args, **kwargs)
#      92         return wrapper
#      93     return _deprecate_kwarg
#
# /anaconda/lib/python2.7/site-packages/pandas/core/generic.pyc in astype(self, dtype, copy, errors, **kwargs)
#    3297         # else, only a single dtype is given
#    3298         new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors,
# -> 3299                                      **kwargs)
# ...

# %%
result
# Out:
#         State Code  County Code  Site Num  Parameter Code  POC   Latitude  \
# 0                1           89         3           12128    1  34.728831
# 1                1           89         3           12128    1  34.728831
# 2                1           89         3           12128    1  34.728831
# 3                1           89         3           12128    1  34.728831
# 4                1           89         3           12128    1  34.728831
# 5                1           89         3           12128    1  34.728831
# 6                1           89         3           12128    1  34.728831
# 7                1           89         3           12128    1  34.728831
# 8                1           89         3           12128    1  34.728831
# 9                1           89         3           12128    1  34.728831
# 10               1           89         3           12128    1  34.728831
# 11               1           89         3           12128    1  34.728831
# ...

# %%
result.to_csv(path_or_buf="/Users/srinivvx/Desktop/w209 Dashboard/w209_Group_Project-master/Data/Toxics-Lead-Daily/Toxics_Lead_Consolidated.csv", header=True, index=True, index_label="row_num")

# %%
df_test = pd.read_csv("/Users/srinivvx/Desktop/w209 Dashboard/w209_Group_Project-master/Data/Toxics-Lead-Daily/Toxics_Lead_Consolidated.csv")

# %%
df_test
# Out:
#         row_num  State Code  County Code  Site Num  Parameter Code  POC  \
# 0             0           1           89         3           12128    1
# 1             1           1           89         3           12128    1
# 2             2           1           89         3           12128    1
# 3             3           1           89         3           12128    1
# 4             4           1           89         3           12128    1
# 5             5           1           89         3           12128    1
# 6             6           1           89         3           12128    1
# 7             7           1           89         3           12128    1
# 8             8           1           89         3           12128    1
# 9             9           1           89         3           12128    1
# 10           10           1           89         3           12128    1
# 11           11           1           89         3           12128    1
# ...
